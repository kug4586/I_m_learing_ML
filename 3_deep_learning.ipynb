# %% [markdown]
# # 3. 딥러닝

# %% [markdown]
# ## (1) 데이터 전처리

# %%
# 필요 라이브러리 선언
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 읽기
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784')

x_org, y_org = mnist.data, mnist.target
y_org = y_org.astype(np.int) # mnist.target이 문자 배열이기 때문에 이를 정수 배열로 변환함.

# %%
# 입력 데이터의 가공

# 다루기 쉽게 바꾸자
x_org = np.array(x_org)
y_org = np.array(y_org)

# step1 데이터 정규화 값의 범위를 [0, 1]로 제한
x_norm = x_org / 255.0

# 앞에 더미 데이터 변수(1)를 추가
x_all = np.insert(x_norm, 0, 1, axis=1)

print('더미 변수 추가 후', x_all.shape)
# Out:
# 더미 변수 추가 후 (70000, 785)

# %%
# step 2 y를 One-hot-Vector로
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False)
y_all_one = ohe.fit_transform(np.c_[y_org])
print('원핫 인코딩', y_all_one.shape)
# Out:
# 원핫 인코딩 (70000, 10)

# %%
# step 3 학습 데이터와 검증 데이터로 분할
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test, y_train_one, y_test_one = train_test_split(
    x_all, y_org, y_all_one, train_size=60000, test_size=10000, shuffle=False)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape, 
    y_train_one.shape, y_test_one.shape)
# Out:
# (60000, 785) (10000, 785) (60000,) (10000,) (60000, 10) (10000, 10)

# %%
# 데이터 내용 확인
N = 20
np.random.seed(123)
indexes = np.random.choice(y_test.shape[0], N, replace=False)
x_selected = x_test[indexes, 1:]
y_selected = y_test[indexes]
plt.figure(figsize=(10, 3))
for i in range(N):
    ax = plt.subplot(2, N/2, i + 1)
    plt.imshow(x_selected[i].reshape(28, 28),cmap='gray_r')
    ax.set_title('%d' %y_selected[i], fontsize=16)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## (2) 1차 학습

# %%
# 시그모이드 함수
def sigmoid(x):
    return 1/(1+ np.exp(-x))

# 소프트맥스 함수
def softmax(x):
    x = x.T
    x_max = x.max(axis=0)
    x = x - x_max
    w = np.exp(x)
    return (w / w.sum(axis=0)).T

# %%
# 교차 엔트로피 함수
def cross_entropy(yt, yp):
    return -np.mean(np.sum(yt * np.log(yp), axis=1))

# 검증 처리(리턴 값은 정확도와 손실함수)
from sklearn.metrics import accuracy_score
def evaluate(x_test, y_test, y_test_one, V, W):
    b1_test = np.insert(sigmoid(x_test @ V), 0, 1, axis=1)
    yp_test_one = softmax(b1_test @ W)
    yp_test = np.argmax(yp_test_one, axis=1)
    loss = cross_entropy(y_test_one, yp_test_one)
    score = accuracy_score(y_test, yp_test)
    return score, loss

# %%
# 미니 배치용 인덱스 취득 함수
import numpy as np

class Indexes():
    # 생성자
    def __init__(self, total, size):
        # 배열 전체의 크기
        self.total = total
        # 배치 크기
        self.size = size
        # 작업용 인덱스 초기값은 NULL로 한다.
        self.indexes = np.zeros(0)
        
    # 인덱스 취득 함수   
    def next_index(self):
        next_flag = False
        # 배치 크기보다 작업용 인덱스가 작은 경우 인덱스를 재생성
        if len(self.indexes) < self.size: 
            self.indexes = np.random.choice(self.total, 
                self.total, replace=False)
            next_flag = True
        # 복귀용 인덱스 취득과 작업용 인덱스 갱신
        index = self.indexes[:self.size]
        self.indexes = self.indexes[self.size:]
        return index, next_flag

# %%
# 인덱스 클래스의 테스트

# 클래스 초기화
# 20: 전체 배열의 크기 -> 전체 데이터 수
# 5: 한번에 가져오는 인덱스 수 -> 한 번의 배치에 사용될 데이터의 수
indexes = Indexes(20, 5)

for i in range(6):
    # next_index 함수 호출
    # 리턴 값1: 인덱스의 numpy 배열
    # 리턴 값2: 작업용 인덱스가 갱신되었는지의 여부
    arr, flag = indexes.next_index()
    print(arr, flag)
# Out:
# [15  6 11 13 10] True
# [ 7  8  2 17 14] False
# [ 0 16  3 12  5] False
# [ 9 19  1 18  4] False
# [14  4  2 19  7] True
# [18  9  1 11 15] False

# %%
# 변수 초기 선언 

# 은닉층의 노드 개수
H = 128
H1 = H + 1
# M: 학습용 데이터 계열의 전체 개수
M  = x_train.shape[0]
# D: 입력 데이터의 차원 수
D = x_train.shape[1]
# N: 분류 클래스의 개수
N = y_train_one.shape[1]

# 반복 횟수
nb_epoch = 100
# 미니 배치 크기
batch_size = 512
B = batch_size
# 학습률
alpha = 0.01
# 가중치 행렬의 초기 설정(모든 값이 1)
V = np.ones((D, H))
W = np.ones((H1, N))

# 검증 결과 기록(손실함수와 정확도)
history1 = np.zeros((0, 3))
# 미니 배치를 위한 초기화
indexes = Indexes(M, batch_size)
# 반복 횟수 카운터 초기화
epoch = 0

# %%
# 주요 처리
while epoch < nb_epoch:

    # 학습대상 선택(미니 배치 학습법)
    index, next_flag = indexes.next_index()
    x, yt = x_train[index], y_train_one[index]
    
    # 예측값 계산(순전파)
    a = x @ V                         # (10.6.3)
    b = sigmoid(a)                    # (10.6.4)
    b1 = np.insert(b, 0, 1, axis=1)   # 더미 변수의 추가 
    u = b1 @ W                        # (10.6.5)   
    yp = softmax(u)                   # (10.6.6)
    
    # 오차 계산
    yd = yp - yt                      # (10.6.7)
    bd = b * (1-b) * (yd @ W[1:].T)   # (10.6.8)

    # 기울기 계산
    W = W - alpha * (b1.T @ yd) / B   # (10.6.9)
    V = V - alpha * (x.T @ bd) / B    # (10.6.10)
    
    # 로그 기록
    if next_flag: # 1 epoch 종료 후의 처리
        score, loss = evaluate(
            x_test, y_test, y_test_one, V, W)
        history1 = np.vstack((history1, 
            np.array([epoch, loss, score])))
        print("epoch = %d     loss = %f     accuracy = %f" 
            % (epoch, loss, score))
        epoch = epoch + 1
# Out:
# epoch = 0     loss = 2.302479     accuarcy = 0.102800
# epoch = 1     loss = 2.301592     accuarcy = 0.113500
# epoch = 2     loss = 2.302384     accuarcy = 0.102800
# epoch = 3     loss = 2.301277     accuarcy = 0.113500
# epoch = 4     loss = 2.302450     accuarcy = 0.113500
# epoch = 5     loss = 2.301220     accuarcy = 0.113500
# epoch = 6     loss = 2.301395     accuarcy = 0.113500
# epoch = 7     loss = 2.301708     accuarcy = 0.113500
# epoch = 8     loss = 2.301471     accuarcy = 0.113500
# epoch = 9     loss = 2.301243     accuarcy = 0.113500
# epoch = 10     loss = 2.301307     accuarcy = 0.113500
# epoch = 11     loss = 2.301092     accuarcy = 0.113500
# epoch = 12     loss = 2.302035     accuarcy = 0.098000
# epoch = 13     loss = 2.301687     accuarcy = 0.113500
# epoch = 14     loss = 2.301405     accuarcy = 0.113500
# epoch = 15     loss = 2.301894     accuarcy = 0.113500
# epoch = 16     loss = 2.301205     accuarcy = 0.113500
# epoch = 17     loss = 2.301401     accuarcy = 0.113500
# epoch = 18     loss = 2.301538     accuarcy = 0.113500
# epoch = 19     loss = 2.301317     accuarcy = 0.113500
# epoch = 20     loss = 2.301825     accuarcy = 0.113500
# epoch = 21     loss = 2.301453     accuarcy = 0.113500
# epoch = 22     loss = 2.301538     accuarcy = 0.113500
# epoch = 23     loss = 2.301157     accuarcy = 0.113500
# epoch = 24     loss = 2.301234     accuarcy = 0.113500
# epoch = 25     loss = 2.302313     accuarcy = 0.113500
# epoch = 26     loss = 2.302174     accuarcy = 0.102800
# epoch = 27     loss = 2.301799     accuarcy = 0.102800
# epoch = 28     loss = 2.301560     accuarcy = 0.113500
# epoch = 29     loss = 2.302329     accuarcy = 0.113500
# epoch = 30     loss = 2.301371     accuarcy = 0.113500
# epoch = 31     loss = 2.301794     accuarcy = 0.113500
# epoch = 32     loss = 2.301342     accuarcy = 0.113500
# epoch = 33     loss = 2.301714     accuarcy = 0.113500
# epoch = 34     loss = 2.301789     accuarcy = 0.113500
# epoch = 35     loss = 2.301493     accuarcy = 0.113500
# epoch = 36     loss = 2.301175     accuarcy = 0.113500
# epoch = 37     loss = 2.301858     accuarcy = 0.113500
# epoch = 38     loss = 2.301685     accuarcy = 0.113500
# epoch = 39     loss = 2.301489     accuarcy = 0.113500
# epoch = 40     loss = 2.301322     accuarcy = 0.113500
# epoch = 41     loss = 2.301504     accuarcy = 0.113500
# epoch = 42     loss = 2.301572     accuarcy = 0.102800
# epoch = 43     loss = 2.301631     accuarcy = 0.113500
# epoch = 44     loss = 2.301290     accuarcy = 0.113500
# epoch = 45     loss = 2.301316     accuarcy = 0.113500
# epoch = 46     loss = 2.301705     accuarcy = 0.113500
# epoch = 47     loss = 2.301821     accuarcy = 0.113500
# epoch = 48     loss = 2.301843     accuarcy = 0.113500
# epoch = 49     loss = 2.301644     accuarcy = 0.113500
# epoch = 50     loss = 2.301651     accuarcy = 0.113500
# epoch = 51     loss = 2.301635     accuarcy = 0.113500
# epoch = 52     loss = 2.301282     accuarcy = 0.113500
# epoch = 53     loss = 2.301425     accuarcy = 0.113500
# epoch = 54     loss = 2.301857     accuarcy = 0.113500
# epoch = 55     loss = 2.301396     accuarcy = 0.113500
# epoch = 56     loss = 2.301721     accuarcy = 0.113500
# epoch = 57     loss = 2.301936     accuarcy = 0.113500
# epoch = 58     loss = 2.302334     accuarcy = 0.102800
# epoch = 59     loss = 2.301301     accuarcy = 0.113500
# epoch = 60     loss = 2.301295     accuarcy = 0.113500
# epoch = 61     loss = 2.301449     accuarcy = 0.113500
# epoch = 62     loss = 2.301029     accuarcy = 0.113500
# epoch = 63     loss = 2.302886     accuarcy = 0.102800
# epoch = 64     loss = 2.301373     accuarcy = 0.113500
# epoch = 65     loss = 2.301421     accuarcy = 0.113500
# epoch = 66     loss = 2.301245     accuarcy = 0.113500
# epoch = 67     loss = 2.301260     accuarcy = 0.102800
# epoch = 68     loss = 2.301804     accuarcy = 0.101000
# epoch = 69     loss = 2.302164     accuarcy = 0.113500
# epoch = 70     loss = 2.301406     accuarcy = 0.113500
# epoch = 71     loss = 2.301441     accuarcy = 0.113500
# epoch = 72     loss = 2.301109     accuarcy = 0.113500
# epoch = 73     loss = 2.301508     accuarcy = 0.113500
# epoch = 74     loss = 2.302111     accuarcy = 0.102800
# epoch = 75     loss = 2.301814     accuarcy = 0.113500
# epoch = 76     loss = 2.301450     accuarcy = 0.113500
# epoch = 77     loss = 2.302091     accuarcy = 0.113500
# epoch = 78     loss = 2.301262     accuarcy = 0.113500
# epoch = 79     loss = 2.301700     accuarcy = 0.113500
# epoch = 80     loss = 2.301697     accuarcy = 0.113500
# epoch = 81     loss = 2.301506     accuarcy = 0.113500
# epoch = 82     loss = 2.301430     accuarcy = 0.113500
# epoch = 83     loss = 2.302251     accuarcy = 0.113500
# epoch = 84     loss = 2.301543     accuarcy = 0.113500
# epoch = 85     loss = 2.302334     accuarcy = 0.095800
# epoch = 86     loss = 2.301214     accuarcy = 0.113500
# epoch = 87     loss = 2.301515     accuarcy = 0.113500
# epoch = 88     loss = 2.301069     accuarcy = 0.113500
# epoch = 89     loss = 2.302004     accuarcy = 0.113500
# epoch = 90     loss = 2.301303     accuarcy = 0.113500
# epoch = 91     loss = 2.301356     accuarcy = 0.113500
# epoch = 92     loss = 2.301400     accuarcy = 0.113500
# epoch = 93     loss = 2.301823     accuarcy = 0.113500
# epoch = 94     loss = 2.301307     accuarcy = 0.113500
# epoch = 95     loss = 2.301655     accuarcy = 0.113500
# epoch = 96     loss = 2.301890     accuarcy = 0.100900
# epoch = 97     loss = 2.301743     accuarcy = 0.113500
# epoch = 98     loss = 2.301367     accuarcy = 0.113500
# epoch = 99     loss = 2.301891     accuarcy = 0.113500

# %%
#손실함수와 정확도의 확인
print('[초기 상태] 손실함수: %f, 정확도: %f'
        % (history1[0,1], history1[0,2]))
print('[최종 상태] 손실함수: %f, 정확도: %f'
        % (history1[-1,1], history1[-1,2]))

# 학습 곡선 표시(손실함수의 값)
plt.plot(history1[:,0], history1[:,1])
plt.ylim(0,2.5)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()

# 학습 곡선 표시(정확도)
plt.plot(history1[:,0], history1[:,2])
plt.ylim(0,1)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()
# Out:
# [초기 상태] 손실함수: 2.302479, 정확도: 0.102800
# [최종 상태] 손실함수: 2.301891, 정확도: 0.113500

# %% [markdown]
# ## (3) 2차 학습

# %%
# 변수 초기 선언 가중치 행렬의 초기화 방식 변경

# 은닉층의 노드 개수
H = 128
H1 = H + 1
# M: 학습용 데이터 계열의 전체 개수
M  = x_train.shape[0]
# D: 입력 데이터의 차원 수
D = x_train.shape[1]
# N: 분류 클래스의 개수
N = y_train_one.shape[1]

# 기계 학습 매개변수
alpha = 0.01
nb_epoch = 100
batch_size = 512
B = batch_size
# 개선된 가중치 행렬의 초기화
V = np.random.randn(D, H) / np.sqrt(D / 2)
W = np.random.randn(H1, N) / np.sqrt(H1 / 2)
# 가중치 행렬의 초기 설정(모든 값이 1)
V = np.ones((D, H))
W = np.ones((H1, N))

# 검증 결과 기록(손실함수와 정확도)
history2 = np.zeros((0, 3))
# 미니 배치를 위한 초기화
indexes = Indexes(M, B)
# 반복 횟수 카운터 초기화
epoch = 0

print(V)
print(W)
# Out:
# [[ 0.01606073 -0.00589595 -0.05673273  0.04396212  0.04685946]
#  [-0.0178378  -0.04058216 -0.06454661  0.00383612  0.00712562]]
# [[-0.13315159 -0.05544828  0.17478607  0.02236453 -0.05550712]
#  [-0.04156405  0.03331514  0.10278515  0.00901622 -0.11052494]]

# %%
# 주요 처리
while epoch < nb_epoch:
    
    # 학습대상 선택(미니 배치 학습법)
    index, next_flag = indexes.next_index()
    x, yt = x_train[index], y_train_one[index]

    # 예측값 계산(순전파)
    a = x @ V                         # (10.6.3)
    b = sigmoid(a)                    # (10.6.4)
    b1 = np.insert(b, 0, 1, axis=1)   # 더미 변수의 추가
    u = b1 @ W                        # (10.6.5)
    yp = softmax(u)                   # (10.6.6)
    
    # 오차 계산
    yd = yp - yt                      # (10.6.7)
    bd = b * (1-b) * (yd @ W[1:].T)   # (10.6.8)

    # 기울기 계산
    W = W - alpha * (b1.T @ yd) / B   # (10.6.9)
    V = V - alpha * (x.T @ bd) / B    # (10.6.10)

    if next_flag: # 1epoch 종료 후의 처리
        score, loss = evaluate(
            x_test, y_test, y_test_one, V, W)
        history2 = np.vstack((history2, 
            np.array([epoch, loss, score])))
        print("epoch = %d      loss = %f      accuracy = %f" 
            % (epoch, loss, score))
        epoch = epoch + 1
# Out:
# epoch = 0      loss = 2.475303      accuracy = 0.098200
# epoch = 1      loss = 2.165526      accuracy = 0.370400
# epoch = 2      loss = 2.013865      accuracy = 0.563900
# epoch = 3      loss = 1.873786      accuracy = 0.652500
# epoch = 4      loss = 1.742799      accuracy = 0.697200
# epoch = 5      loss = 1.621452      accuracy = 0.729500
# epoch = 6      loss = 1.508871      accuracy = 0.748100
# epoch = 7      loss = 1.406047      accuracy = 0.764900
# epoch = 8      loss = 1.312973      accuracy = 0.780500
# epoch = 9      loss = 1.229245      accuracy = 0.788300
# epoch = 10      loss = 1.154316      accuracy = 0.800200
# epoch = 11      loss = 1.088013      accuracy = 0.807500
# epoch = 12      loss = 1.029048      accuracy = 0.812600
# epoch = 13      loss = 0.976628      accuracy = 0.820700
# epoch = 14      loss = 0.930074      accuracy = 0.825300
# epoch = 15      loss = 0.888620      accuracy = 0.830300
# epoch = 16      loss = 0.851577      accuracy = 0.832500
# epoch = 17      loss = 0.818268      accuracy = 0.838000
# epoch = 18      loss = 0.788400      accuracy = 0.840500
# epoch = 19      loss = 0.761233      accuracy = 0.843800
# epoch = 20      loss = 0.736578      accuracy = 0.846700
# epoch = 21      loss = 0.714228      accuracy = 0.849300
# epoch = 22      loss = 0.693703      accuracy = 0.852200
# epoch = 23      loss = 0.674997      accuracy = 0.854900
# epoch = 24      loss = 0.657695      accuracy = 0.857200
# epoch = 25      loss = 0.641650      accuracy = 0.860100
# epoch = 26      loss = 0.626792      accuracy = 0.862600
# epoch = 27      loss = 0.613082      accuracy = 0.863700
# epoch = 28      loss = 0.600294      accuracy = 0.865500
# epoch = 29      loss = 0.588370      accuracy = 0.867700
# epoch = 30      loss = 0.577176      accuracy = 0.868300
# epoch = 31      loss = 0.566703      accuracy = 0.869800
# epoch = 32      loss = 0.556820      accuracy = 0.871800
# epoch = 33      loss = 0.547532      accuracy = 0.872500
# epoch = 34      loss = 0.538837      accuracy = 0.873900
# epoch = 35      loss = 0.530497      accuracy = 0.875500
# epoch = 36      loss = 0.522800      accuracy = 0.876700
# epoch = 37      loss = 0.515427      accuracy = 0.877800
# epoch = 38      loss = 0.508341      accuracy = 0.879200
# epoch = 39      loss = 0.501726      accuracy = 0.880600
# epoch = 40      loss = 0.495478      accuracy = 0.881100
# epoch = 41      loss = 0.489374      accuracy = 0.881300
# epoch = 42      loss = 0.483588      accuracy = 0.882400
# epoch = 43      loss = 0.478127      accuracy = 0.883100
# epoch = 44      loss = 0.472949      accuracy = 0.883800
# epoch = 45      loss = 0.467950      accuracy = 0.884700
# epoch = 46      loss = 0.463199      accuracy = 0.885700
# epoch = 47      loss = 0.458629      accuracy = 0.885400
# epoch = 48      loss = 0.454208      accuracy = 0.886300
# epoch = 49      loss = 0.449965      accuracy = 0.886500
# epoch = 50      loss = 0.446054      accuracy = 0.887100
# epoch = 51      loss = 0.442076      accuracy = 0.888000
# epoch = 52      loss = 0.438359      accuracy = 0.888700
# epoch = 53      loss = 0.434748      accuracy = 0.889200
# epoch = 54      loss = 0.431301      accuracy = 0.890100
# epoch = 55      loss = 0.427897      accuracy = 0.890900
# epoch = 56      loss = 0.424782      accuracy = 0.891100
# epoch = 57      loss = 0.421650      accuracy = 0.891600
# epoch = 58      loss = 0.418597      accuracy = 0.892200
# epoch = 59      loss = 0.415795      accuracy = 0.893200
# epoch = 60      loss = 0.412928      accuracy = 0.893100
# epoch = 61      loss = 0.410187      accuracy = 0.893800
# epoch = 62      loss = 0.407657      accuracy = 0.894500
# epoch = 63      loss = 0.405061      accuracy = 0.894700
# epoch = 64      loss = 0.402664      accuracy = 0.895200
# epoch = 65      loss = 0.400281      accuracy = 0.895600
# epoch = 66      loss = 0.397916      accuracy = 0.896400
# epoch = 67      loss = 0.395637      accuracy = 0.896400
# epoch = 68      loss = 0.393509      accuracy = 0.896200
# epoch = 69      loss = 0.391400      accuracy = 0.896400
# epoch = 70      loss = 0.389320      accuracy = 0.896800
# epoch = 71      loss = 0.387406      accuracy = 0.897300
# epoch = 72      loss = 0.385431      accuracy = 0.897100
# epoch = 73      loss = 0.383570      accuracy = 0.897100
# epoch = 74      loss = 0.381616      accuracy = 0.897500
# epoch = 75      loss = 0.379930      accuracy = 0.897500
# epoch = 76      loss = 0.378109      accuracy = 0.897600
# epoch = 77      loss = 0.376393      accuracy = 0.897900
# epoch = 78      loss = 0.374702      accuracy = 0.898200
# epoch = 79      loss = 0.373085      accuracy = 0.898200
# epoch = 80      loss = 0.371451      accuracy = 0.898900
# epoch = 81      loss = 0.370020      accuracy = 0.898500
# epoch = 82      loss = 0.368544      accuracy = 0.898900
# epoch = 83      loss = 0.367042      accuracy = 0.899800
# epoch = 84      loss = 0.365560      accuracy = 0.900100
# epoch = 85      loss = 0.364151      accuracy = 0.900700
# epoch = 86      loss = 0.362839      accuracy = 0.899700
# epoch = 87      loss = 0.361357      accuracy = 0.900300
# epoch = 88      loss = 0.360092      accuracy = 0.900700
# epoch = 89      loss = 0.358807      accuracy = 0.900600
# epoch = 90      loss = 0.357609      accuracy = 0.900900
# epoch = 91      loss = 0.356318      accuracy = 0.900800
# epoch = 92      loss = 0.355142      accuracy = 0.901200
# epoch = 93      loss = 0.353958      accuracy = 0.901500
# epoch = 94      loss = 0.352745      accuracy = 0.901400
# epoch = 95      loss = 0.351686      accuracy = 0.901900
# epoch = 96      loss = 0.350500      accuracy = 0.902100
# epoch = 97      loss = 0.349518      accuracy = 0.902600
# epoch = 98      loss = 0.348290      accuracy = 0.902600
# epoch = 99      loss = 0.347259      accuracy = 0.903100

# %%
# 손실함수와 정확도의 확인
print('[초기 상태] 손실함수: %f, 정확도: %f'
        % (history2[0,1], history2[0,2]))
print('[최종 상태] 손실함수: %f, 정확도: %f'
        % (history2[-1,1], history2[-1,2]))
print('\n')

# 학습 곡선 표시(손실함수의 값)
plt.plot(history2[:,0], history2[:,1])
plt.ylim(0,2.5)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()

# 학습 곡선 표시(정확도)
plt.plot(history2[:,0], history2[:,2])
plt.ylim(0,1)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()
# Out:
# [초기 상태] 손실함수: 2.475303, 정확도: 0.098200
# [최종 상태] 손실함수: 0.347259, 정확도: 0.903100

# %% [markdown]
# ## (4) 3차 학습

# %%
# ReLU 함수
def ReLU(x):
    return np.maximum(0, x)

# 계단함수
def step(x):
    return 1.0 * ( x > 0)

# %%
# ReLU 함수와 계단함수의 그래프 표시

xx =  np.linspace(-4, 4, 501)
yy = ReLU(xx)
plt.figure(figsize=(6,6))
#plt.ylim(0.0, 1.0)
plt.xlim(-4, 4)
plt.ylim(-4, 4)
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$y$', fontsize=14)
plt.grid(lw=2)
plt.plot(xx, ReLU(xx), c='b', label='ReLU', linestyle='-', lw=3)
plt.plot(xx, step(xx), c='k', label='step', linestyle='-.', lw=3)
plt.xticks(size=14)
plt.yticks(size=14)
plt.legend(fontsize=14)
plt.show()

# %%
# 검증 처리 (ReLU 함수 지원)
from sklearn.metrics import accuracy_score
def evaluate2(x_test, y_test, y_test_one, V, W):
    b1_test = np.insert(ReLU(x_test @ V), 0, 1, axis=1)
    yp_test_one = softmax(b1_test @ W)
    yp_test = np.argmax(yp_test_one, axis=1)
    loss = cross_entropy(y_test_one, yp_test_one)
    score = accuracy_score(y_test, yp_test)
    return score, loss

# %%
# 변수 초기 선언 가중치 행렬의 초기화 방식 변경

# 은닉층의 노드 개수
H = 128
H1 = H + 1
# M: 학습용 데이터 계열의 전체 개수
M  = x_train.shape[0]
# D: 입력 데이터의 차원 수
D = x_train.shape[1]
# N: 분류 클래스의 개수
N = y_train_one.shape[1]

# 기계 학습 매개변수
alpha = 0.01
nb_epoch = 100
batch_size = 512
B = batch_size
# 가중치 행렬의 초기 설정
V = np.random.randn(D, H) / np.sqrt(D / 2)
W = np.random.randn(H1, N) / np.sqrt(H1 / 2)

# 검증 결과 기록(손실함수와 정확도)
history3 = np.zeros((0, 3))
# 미니 배치를 위한 초기화
indexes = Indexes(M, batch_size)
# 반복 횟수 카운터 초기화
epoch = 0

# %%
# 주요 처리 (시그모이드 함수를 ReLU 함수로 변경)
while epoch < nb_epoch:
    
    # 학습대상 선택(미니 배치 학습법)
    index, next_flag = indexes.next_index()
    x, yt = x_train[index], y_train_one[index]

    # 예측값 계산(순전파)
    a = x @ V                         # (10.6.3)
    b = ReLU(a)                       # (10.6.4) ReLU 함수로 교체
    b1 = np.insert(b, 0, 1, axis=1)   # 더미 변수의 추가 
    u = b1 @ W                        # (10.6.5)   
    yp = softmax(u)                   # (10.6.6)
    
    # 오차 계산
    yd = yp - yt                      # (10.6.7)
    bd = step(a) * (yd @ W[1:].T)     #(10.6.8) 계단함수로 교체

    # 기울기 계산
    W = W - alpha * (b1.T @ yd) / B   # (10.6.9)
    V = V - alpha * (x.T @ bd) / B    # (10.6.10)

    if next_flag: # 1epoch 종료 후의 처리
        score, loss = evaluate2(
            x_test, y_test, y_test_one, V, W)
        history3 = np.vstack((history3, 
            np.array([epoch, loss, score])))
        print("epoch = %d loss = %f score = %f" 
            % (epoch, loss, score))
        epoch = epoch + 1
# Out:
# epoch = 0 loss = 2.397303 score = 0.095500
# epoch = 1 loss = 1.422963 score = 0.704700
# epoch = 2 loss = 0.942274 score = 0.807200
# epoch = 3 loss = 0.729103 score = 0.841700
# epoch = 4 loss = 0.618426 score = 0.859500
# epoch = 5 loss = 0.550204 score = 0.869600
# epoch = 6 loss = 0.504587 score = 0.875300
# epoch = 7 loss = 0.471058 score = 0.883000
# epoch = 8 loss = 0.445631 score = 0.885700
# epoch = 9 loss = 0.425837 score = 0.889100
# epoch = 10 loss = 0.409313 score = 0.892900
# epoch = 11 loss = 0.395532 score = 0.896200
# epoch = 12 loss = 0.384107 score = 0.897700
# epoch = 13 loss = 0.374044 score = 0.899800
# epoch = 14 loss = 0.365188 score = 0.902100
# epoch = 15 loss = 0.357590 score = 0.903500
# epoch = 16 loss = 0.350587 score = 0.904900
# epoch = 17 loss = 0.344183 score = 0.906500
# epoch = 18 loss = 0.338456 score = 0.907400
# epoch = 19 loss = 0.333481 score = 0.908400
# epoch = 20 loss = 0.328270 score = 0.909800
# epoch = 21 loss = 0.323783 score = 0.911100
# epoch = 22 loss = 0.319697 score = 0.911200
# epoch = 23 loss = 0.315629 score = 0.912400
# epoch = 24 loss = 0.312309 score = 0.912200
# epoch = 25 loss = 0.308782 score = 0.913100
# epoch = 26 loss = 0.305296 score = 0.913900
# epoch = 27 loss = 0.302262 score = 0.914700
# epoch = 28 loss = 0.298973 score = 0.915200
# epoch = 29 loss = 0.296221 score = 0.915500
# epoch = 30 loss = 0.293821 score = 0.916100
# epoch = 31 loss = 0.290782 score = 0.917300
# epoch = 32 loss = 0.288541 score = 0.916700
# epoch = 33 loss = 0.286006 score = 0.917500
# epoch = 34 loss = 0.283631 score = 0.918800
# epoch = 35 loss = 0.281408 score = 0.918900
# epoch = 36 loss = 0.279486 score = 0.919900
# epoch = 37 loss = 0.276757 score = 0.919900
# epoch = 38 loss = 0.274874 score = 0.919600
# epoch = 39 loss = 0.273029 score = 0.920600
# epoch = 40 loss = 0.271279 score = 0.921300
# epoch = 41 loss = 0.269273 score = 0.922700
# epoch = 42 loss = 0.267409 score = 0.922200
# epoch = 43 loss = 0.265429 score = 0.923200
# epoch = 44 loss = 0.263896 score = 0.923400
# epoch = 45 loss = 0.262216 score = 0.923900
# epoch = 46 loss = 0.260282 score = 0.923900
# epoch = 47 loss = 0.258869 score = 0.924200
# epoch = 48 loss = 0.257276 score = 0.925200
# epoch = 49 loss = 0.255770 score = 0.926200
# epoch = 50 loss = 0.254235 score = 0.926200
# epoch = 51 loss = 0.252540 score = 0.926900
# epoch = 52 loss = 0.251219 score = 0.927500
# epoch = 53 loss = 0.249694 score = 0.928200
# epoch = 54 loss = 0.248301 score = 0.928000
# epoch = 55 loss = 0.246934 score = 0.928000
# epoch = 56 loss = 0.245484 score = 0.929100
# epoch = 57 loss = 0.244000 score = 0.929400
# epoch = 58 loss = 0.242874 score = 0.929900
# epoch = 59 loss = 0.241466 score = 0.930200
# epoch = 60 loss = 0.240334 score = 0.930400
# epoch = 61 loss = 0.239145 score = 0.930600
# epoch = 62 loss = 0.237911 score = 0.930600
# epoch = 63 loss = 0.236325 score = 0.931200
# epoch = 64 loss = 0.235422 score = 0.931400
# epoch = 65 loss = 0.234108 score = 0.931500
# epoch = 66 loss = 0.233237 score = 0.931800
# epoch = 67 loss = 0.231909 score = 0.933100
# epoch = 68 loss = 0.230798 score = 0.932300
# epoch = 69 loss = 0.229659 score = 0.933300
# epoch = 70 loss = 0.228374 score = 0.933600
# epoch = 71 loss = 0.227183 score = 0.934000
# epoch = 72 loss = 0.226068 score = 0.934500
# epoch = 73 loss = 0.225074 score = 0.934500
# epoch = 74 loss = 0.223943 score = 0.934800
# epoch = 75 loss = 0.223101 score = 0.935100
# epoch = 76 loss = 0.221851 score = 0.935600
# epoch = 77 loss = 0.221097 score = 0.935000
# epoch = 78 loss = 0.219955 score = 0.936100
# epoch = 79 loss = 0.218775 score = 0.936500
# epoch = 80 loss = 0.218072 score = 0.936500
# epoch = 81 loss = 0.216883 score = 0.937100
# epoch = 82 loss = 0.215900 score = 0.937200
# epoch = 83 loss = 0.215015 score = 0.937100
# epoch = 84 loss = 0.214176 score = 0.937200
# epoch = 85 loss = 0.213110 score = 0.937600
# epoch = 86 loss = 0.212388 score = 0.937900
# epoch = 87 loss = 0.211237 score = 0.938300
# epoch = 88 loss = 0.210267 score = 0.938700
# epoch = 89 loss = 0.209413 score = 0.938800
# epoch = 90 loss = 0.208649 score = 0.938200
# epoch = 91 loss = 0.207597 score = 0.939200
# epoch = 92 loss = 0.206732 score = 0.939200
# epoch = 93 loss = 0.205867 score = 0.939400
# epoch = 94 loss = 0.205116 score = 0.940000
# epoch = 95 loss = 0.204344 score = 0.939700
# epoch = 96 loss = 0.203323 score = 0.940500
# epoch = 97 loss = 0.202738 score = 0.941000
# epoch = 98 loss = 0.201633 score = 0.941000
# epoch = 99 loss = 0.200852 score = 0.941500

# %%
# 손실함수와 정확도의 확인
print('[초기 상태] 손실함수: %f, 정확도: %f'
        % (history3[0,1], history3[0,2]))
print('[최종 상태] 손실함수: %f, 정확도: %f'
        % (history3[-1,1], history3[-1,2]))
print('\n')

# 학습 곡선 표시(손실함수의 값)
plt.plot(history3[:,0], history3[:,1])
plt.ylim(0,2.5)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()

# 학습 곡선 표시(정확도)
plt.plot(history3[:,0], history3[:,2])
plt.ylim(0,1)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()
# Out:
# [초기 상태] 손실함수: 2.397303, 정확도: 0.095500
# [최종 상태] 손실함수: 0.200852, 정확도: 0.941500

# %%
# 데이터 내용 확인
import matplotlib.pyplot as plt
N = 20
np.random.seed(123)
indexes = np.random.choice(y_test.shape[0], N, replace=False)

# x_org의 선택 결과 표시(흑백 반전)
x_selected = x_test[indexes]
y_selected = y_test[indexes]

# 예측값 계산
b1_test = np.insert(ReLU(x_selected @ V), 0, 1, axis=1)
yp_test_one = softmax(b1_test @ W)
yp_test = np.argmax(yp_test_one, axis=1)

# 그래프 표시
plt.figure(figsize=(10, 3))
for i in range(N):
    ax = plt.subplot(2, N/2, i + 1)
    plt.imshow(x_selected[i,1:].reshape(28, 28),cmap='gray_r')
    ax.set_title('%d:%d' % (y_selected[i], yp_test[i]),fontsize=14 )
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## (5) 4차 학습

# %%
# 검증 처리 (은닉층에 2계층 지원)
from sklearn.metrics import accuracy_score
def evaluate3(x_test, y_test, y_test_one, U, V, W):
    b1_test = np.insert(ReLU(x_test @ U), 0, 1, axis=1)
    d1_test = np.insert(ReLU(b1_test @ V), 0, 1, axis=1)
    yp_test_one = softmax(d1_test @ W)
    yp_test = np.argmax(yp_test_one, axis=1)
    loss = cross_entropy(y_test_one, yp_test_one)
    score = accuracy_score(y_test, yp_test)
    return score, loss

# %%
# 변수 초기 선언 가중치 행렬의 초기화 방식 변경

# 은닉층의 노드 개수
H = 128
H1 = H + 1
# M: 학습용 데이터 계열의 전체 개수
M  = x_train.shape[0]
# D: 입력 데이터의 차원 수
D = x_train.shape[1]
# N: 분류 클래스의 개수
N = y_train_one.shape[1]

# 기계 학습 매개변수
alpha = 0.01
nb_epoch = 200
batch_size = 512
B = batch_size
# 가중치 행렬의 초기 설정
U = np.random.randn(D, H) / np.sqrt(D / 2)
V = np.random.randn(H1, H) / np.sqrt(H1 / 2)
W = np.random.randn(H1, N) / np.sqrt(H1 / 2)

# 검증 결과 기록(손실함수와 정확도)
history4 = np.zeros((0, 3))
# 미니 배치를 위한 초기화
indexes = Indexes(M, batch_size)
# 반복 횟수 카운터 초기화
epoch = 0

# %%
# 주요 처리 (은닉층 2계층화)
while epoch < nb_epoch:
    # 학습대상 선택(미니 배치 학습법)
    index, next_flag = indexes.next_index()
    x, yt = x_train[index], y_train_one[index]
    
    # 예측값 계산(순전파)
    a = x @ U                        # (10.6.11)
    b = ReLU(a)                      # (10.6.12)
    b1 = np.insert(b, 0, 1, axis=1)  # 더미 변수의 추가
    c = b1 @ V                       # (10.6.13)
    d = ReLU(c)                      # (10.6.14)
    d1 = np.insert(d, 0, 1, axis=1)  # 더미 변수의 추가
    u = d1 @ W                       # (10.6.15)
    yp = softmax(u)                  # (10.6.16)
    
    # 오차 계산
    yd = yp - yt                     # (10.6.17)
    dd = step(c) * (yd @ W[1:].T)    # (10.6.18)
    bd = step(a) * (dd @ V[1:].T)    # (10.6.19)

    # 기울기 계산
    W = W - alpha * (d1.T @ yd) / B  # (10.6.20)
    V = V - alpha * (b1.T @ dd) / B  # (10.6.21)
    U = U - alpha * (x.T @ bd) / B   # (10.6.22)

    if next_flag: # 1epoch 종료 후의 처리
        score, loss = evaluate3(
            x_test, y_test, y_test_one, U, V, W)
        history4 = np.vstack((history4, 
            np.array([epoch, loss, score])))
        print("epoch = %d      loss = %f      accuracy = %f" 
            % (epoch, loss, score))
        epoch = epoch + 1
# Out:
# epoch = 0      loss = 2.384611      accuracy = 0.112800
# epoch = 1      loss = 1.408489      accuracy = 0.697000
# epoch = 2      loss = 0.851626      accuracy = 0.810400
# epoch = 3      loss = 0.629785      accuracy = 0.845900
# epoch = 4      loss = 0.525465      accuracy = 0.867200
# epoch = 5      loss = 0.464634      accuracy = 0.879400
# epoch = 6      loss = 0.424851      accuracy = 0.888900
# epoch = 7      loss = 0.395783      accuracy = 0.894200
# epoch = 8      loss = 0.374510      accuracy = 0.899200
# epoch = 9      loss = 0.357640      accuracy = 0.903200
# epoch = 10      loss = 0.343602      accuracy = 0.906800
# epoch = 11      loss = 0.332329      accuracy = 0.909500
# epoch = 12      loss = 0.322984      accuracy = 0.911700
# epoch = 13      loss = 0.314158      accuracy = 0.914000
# epoch = 14      loss = 0.306151      accuracy = 0.915400
# epoch = 15      loss = 0.299058      accuracy = 0.917700
# epoch = 16      loss = 0.293303      accuracy = 0.919500
# epoch = 17      loss = 0.288032      accuracy = 0.919900
# epoch = 18      loss = 0.281708      accuracy = 0.922700
# epoch = 19      loss = 0.277978      accuracy = 0.922600
# epoch = 20      loss = 0.273339      accuracy = 0.925400
# epoch = 21      loss = 0.268630      accuracy = 0.926300
# epoch = 22      loss = 0.264274      accuracy = 0.926700
# epoch = 23      loss = 0.260809      accuracy = 0.927300
# epoch = 24      loss = 0.256767      accuracy = 0.928400
# epoch = 25      loss = 0.254306      accuracy = 0.929600
# epoch = 26      loss = 0.249978      accuracy = 0.930200
# epoch = 27      loss = 0.246654      accuracy = 0.931400
# epoch = 28      loss = 0.243502      accuracy = 0.932600
# epoch = 29      loss = 0.239896      accuracy = 0.932700
# epoch = 30      loss = 0.237727      accuracy = 0.933300
# epoch = 31      loss = 0.235145      accuracy = 0.934900
# epoch = 32      loss = 0.232841      accuracy = 0.934400
# epoch = 33      loss = 0.228958      accuracy = 0.936200
# epoch = 34      loss = 0.227252      accuracy = 0.935500
# epoch = 35      loss = 0.224492      accuracy = 0.937100
# epoch = 36      loss = 0.221957      accuracy = 0.936900
# epoch = 37      loss = 0.219252      accuracy = 0.938300
# epoch = 38      loss = 0.217324      accuracy = 0.938500
# epoch = 39      loss = 0.214865      accuracy = 0.939700
# epoch = 40      loss = 0.212874      accuracy = 0.940300
# epoch = 41      loss = 0.210474      accuracy = 0.940200
# epoch = 42      loss = 0.208462      accuracy = 0.941000
# epoch = 43      loss = 0.206547      accuracy = 0.941400
# epoch = 44      loss = 0.204264      accuracy = 0.941400
# epoch = 45      loss = 0.202992      accuracy = 0.942000
# epoch = 46      loss = 0.200207      accuracy = 0.942600
# epoch = 47      loss = 0.198479      accuracy = 0.943000
# epoch = 48      loss = 0.196986      accuracy = 0.943700
# epoch = 49      loss = 0.194989      accuracy = 0.944300
# epoch = 50      loss = 0.193260      accuracy = 0.945100
# epoch = 51      loss = 0.191887      accuracy = 0.944700
# epoch = 52      loss = 0.190571      accuracy = 0.945000
# epoch = 53      loss = 0.188369      accuracy = 0.946200
# epoch = 54      loss = 0.186593      accuracy = 0.946700
# epoch = 55      loss = 0.185411      accuracy = 0.946700
# epoch = 56      loss = 0.183443      accuracy = 0.947300
# epoch = 57      loss = 0.182577      accuracy = 0.947900
# epoch = 58      loss = 0.180277      accuracy = 0.947700
# epoch = 59      loss = 0.178931      accuracy = 0.948000
# epoch = 60      loss = 0.177640      accuracy = 0.948100
# epoch = 61      loss = 0.175862      accuracy = 0.949100
# epoch = 62      loss = 0.174440      accuracy = 0.949000
# epoch = 63      loss = 0.173158      accuracy = 0.949600
# epoch = 64      loss = 0.172382      accuracy = 0.949100
# epoch = 65      loss = 0.170888      accuracy = 0.950600
# epoch = 66      loss = 0.170361      accuracy = 0.950900
# epoch = 67      loss = 0.168206      accuracy = 0.950800
# epoch = 68      loss = 0.166909      accuracy = 0.950700
# epoch = 69      loss = 0.166273      accuracy = 0.951600
# epoch = 70      loss = 0.164746      accuracy = 0.951600
# epoch = 71      loss = 0.163528      accuracy = 0.952900
# epoch = 72      loss = 0.163132      accuracy = 0.952500
# epoch = 73      loss = 0.161729      accuracy = 0.952900
# epoch = 74      loss = 0.160303      accuracy = 0.953200
# epoch = 75      loss = 0.159092      accuracy = 0.953200
# epoch = 76      loss = 0.158073      accuracy = 0.952700
# epoch = 77      loss = 0.156808      accuracy = 0.953400
# epoch = 78      loss = 0.155877      accuracy = 0.953400
# epoch = 79      loss = 0.154736      accuracy = 0.954100
# epoch = 80      loss = 0.154477      accuracy = 0.954500
# epoch = 81      loss = 0.152797      accuracy = 0.954700
# epoch = 82      loss = 0.152033      accuracy = 0.955400
# epoch = 83      loss = 0.151237      accuracy = 0.955700
# epoch = 84      loss = 0.150525      accuracy = 0.955800
# epoch = 85      loss = 0.149414      accuracy = 0.956200
# epoch = 86      loss = 0.148405      accuracy = 0.955800
# epoch = 87      loss = 0.148236      accuracy = 0.956100
# epoch = 88      loss = 0.147074      accuracy = 0.956900
# epoch = 89      loss = 0.146492      accuracy = 0.956400
# epoch = 90      loss = 0.144962      accuracy = 0.957400
# epoch = 91      loss = 0.144454      accuracy = 0.957100
# epoch = 92      loss = 0.143690      accuracy = 0.958300
# epoch = 93      loss = 0.143038      accuracy = 0.957900
# epoch = 94      loss = 0.141970      accuracy = 0.958100
# epoch = 95      loss = 0.141507      accuracy = 0.958800
# epoch = 96      loss = 0.140672      accuracy = 0.959400
# epoch = 97      loss = 0.140573      accuracy = 0.959200
# epoch = 98      loss = 0.139167      accuracy = 0.959400
# epoch = 99      loss = 0.138824      accuracy = 0.959400
# epoch = 100      loss = 0.137493      accuracy = 0.960200
# epoch = 101      loss = 0.136589      accuracy = 0.960600
# epoch = 102      loss = 0.136536      accuracy = 0.960300
# epoch = 103      loss = 0.135329      accuracy = 0.960500
# epoch = 104      loss = 0.134709      accuracy = 0.960700
# epoch = 105      loss = 0.134512      accuracy = 0.961300
# epoch = 106      loss = 0.134091      accuracy = 0.960800
# epoch = 107      loss = 0.132757      accuracy = 0.961300
# epoch = 108      loss = 0.132418      accuracy = 0.961500
# epoch = 109      loss = 0.131645      accuracy = 0.961500
# epoch = 110      loss = 0.131362      accuracy = 0.961500
# epoch = 111      loss = 0.130784      accuracy = 0.961800
# epoch = 112      loss = 0.129586      accuracy = 0.962000
# epoch = 113      loss = 0.129444      accuracy = 0.962300
# epoch = 114      loss = 0.128416      accuracy = 0.963200
# epoch = 115      loss = 0.128225      accuracy = 0.962700
# epoch = 116      loss = 0.127355      accuracy = 0.963000
# epoch = 117      loss = 0.126893      accuracy = 0.963200
# epoch = 118      loss = 0.126523      accuracy = 0.963400
# epoch = 119      loss = 0.125600      accuracy = 0.963900
# epoch = 120      loss = 0.125229      accuracy = 0.963900
# epoch = 121      loss = 0.125156      accuracy = 0.963900
# epoch = 122      loss = 0.124375      accuracy = 0.964000
# epoch = 123      loss = 0.123754      accuracy = 0.964200
# epoch = 124      loss = 0.123735      accuracy = 0.964400
# epoch = 125      loss = 0.122385      accuracy = 0.964500
# epoch = 126      loss = 0.122095      accuracy = 0.964400
# epoch = 127      loss = 0.122591      accuracy = 0.964300
# epoch = 128      loss = 0.121186      accuracy = 0.964900
# epoch = 129      loss = 0.120663      accuracy = 0.964800
# epoch = 130      loss = 0.120532      accuracy = 0.965500
# epoch = 131      loss = 0.120206      accuracy = 0.964700
# epoch = 132      loss = 0.119728      accuracy = 0.965300
# epoch = 133      loss = 0.118756      accuracy = 0.965100
# epoch = 134      loss = 0.119188      accuracy = 0.965100
# epoch = 135      loss = 0.117838      accuracy = 0.965200
# epoch = 136      loss = 0.117405      accuracy = 0.965400
# epoch = 137      loss = 0.117027      accuracy = 0.965700
# epoch = 138      loss = 0.116479      accuracy = 0.965800
# epoch = 139      loss = 0.116036      accuracy = 0.966300
# epoch = 140      loss = 0.115456      accuracy = 0.966300
# epoch = 141      loss = 0.115246      accuracy = 0.966600
# epoch = 142      loss = 0.114555      accuracy = 0.966500
# epoch = 143      loss = 0.114952      accuracy = 0.965800
# epoch = 144      loss = 0.114078      accuracy = 0.966500
# epoch = 145      loss = 0.113837      accuracy = 0.966800
# epoch = 146      loss = 0.113180      accuracy = 0.967100
# epoch = 147      loss = 0.113032      accuracy = 0.967100
# epoch = 148      loss = 0.113479      accuracy = 0.966700
# epoch = 149      loss = 0.112277      accuracy = 0.967400
# epoch = 150      loss = 0.112215      accuracy = 0.967000
# epoch = 151      loss = 0.111093      accuracy = 0.967900
# epoch = 152      loss = 0.111450      accuracy = 0.966900
# epoch = 153      loss = 0.110330      accuracy = 0.968000
# epoch = 154      loss = 0.110277      accuracy = 0.967700
# epoch = 155      loss = 0.110458      accuracy = 0.967100
# epoch = 156      loss = 0.109651      accuracy = 0.967200
# epoch = 157      loss = 0.109152      accuracy = 0.968300
# epoch = 158      loss = 0.108766      accuracy = 0.968000
# epoch = 159      loss = 0.109076      accuracy = 0.967700
# epoch = 160      loss = 0.108684      accuracy = 0.967400
# epoch = 161      loss = 0.107902      accuracy = 0.968100
# epoch = 162      loss = 0.107949      accuracy = 0.967600
# epoch = 163      loss = 0.107251      accuracy = 0.968300
# epoch = 164      loss = 0.107475      accuracy = 0.968200
# epoch = 165      loss = 0.107188      accuracy = 0.967800
# epoch = 166      loss = 0.106745      accuracy = 0.968800
# epoch = 167      loss = 0.106442      accuracy = 0.969200
# epoch = 168      loss = 0.106763      accuracy = 0.968400
# epoch = 169      loss = 0.105638      accuracy = 0.968700
# epoch = 170      loss = 0.105421      accuracy = 0.968800
# epoch = 171      loss = 0.104475      accuracy = 0.969200
# epoch = 172      loss = 0.105060      accuracy = 0.968700
# epoch = 173      loss = 0.104397      accuracy = 0.969500
# epoch = 174      loss = 0.104587      accuracy = 0.969000
# epoch = 175      loss = 0.103681      accuracy = 0.969200
# epoch = 176      loss = 0.103698      accuracy = 0.968900
# epoch = 177      loss = 0.103709      accuracy = 0.968300
# epoch = 178      loss = 0.103059      accuracy = 0.969100
# epoch = 179      loss = 0.102787      accuracy = 0.969700
# epoch = 180      loss = 0.102815      accuracy = 0.968900
# epoch = 181      loss = 0.102405      accuracy = 0.968800
# epoch = 182      loss = 0.101807      accuracy = 0.969700
# epoch = 183      loss = 0.101599      accuracy = 0.969400
# epoch = 184      loss = 0.101144      accuracy = 0.969500
# epoch = 185      loss = 0.100783      accuracy = 0.969600
# epoch = 186      loss = 0.100977      accuracy = 0.969300
# epoch = 187      loss = 0.100986      accuracy = 0.969800
# epoch = 188      loss = 0.100990      accuracy = 0.969700
# epoch = 189      loss = 0.100115      accuracy = 0.969800
# epoch = 190      loss = 0.100389      accuracy = 0.969800
# epoch = 191      loss = 0.100117      accuracy = 0.970300
# epoch = 192      loss = 0.099245      accuracy = 0.970100
# epoch = 193      loss = 0.099092      accuracy = 0.970800
# epoch = 194      loss = 0.099721      accuracy = 0.969700
# epoch = 195      loss = 0.098556      accuracy = 0.970700
# epoch = 196      loss = 0.098540      accuracy = 0.970200
# epoch = 197      loss = 0.098014      accuracy = 0.970300
# epoch = 198      loss = 0.098123      accuracy = 0.970700
# epoch = 199      loss = 0.098049      accuracy = 0.970900

# %%
# 손실함수와 정확도의 확인
print('[초기 상태] 손실함수: %f, 정확도: %f'
    % (history4[1,1], history4[1,2]))
print('[최종 상태] 손실함수: %f, 정확도: %f'
    % (history4[-1,1], history4[-1,2]))
print('\n')

# 학습 곡선 표시(손실함수의 값)
plt.plot(history4[:,0], history4[:,1])
plt.ylim(0,2.5)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()

# 학습 곡선 표시(정확도)
plt.plot(history4[:,0], history4[:,2])
plt.ylim(0,1)
plt.xticks(size=14)
plt.yticks(size=14)
plt.grid(lw=2)
plt.show()
# Out:
# [초기 상태] 손실함수: 1.408489, 정확도: 0.697000
# [최종 상태] 손실함수: 0.098049, 정확도: 0.970900

# %%
# 데이터 내용 확인
import matplotlib.pyplot as plt
N = 20
np.random.seed(111)
indexes = np.random.choice(y_test.shape[0], N, replace=False)

# x_org의 선택 결과 표시(흑백 반전)
x_selected = x_test[indexes]
y_selected = y_test[indexes]

# 예측값 계산
b1_test = np.insert(ReLU(x_selected @ U), 0, 1, axis=1)
d1_test = np.insert(ReLU(b1_test @ V), 0, 1, axis=1)
yp_test_one = softmax(d1_test @ W)
yp_test = np.argmax(yp_test_one, axis=1)

# 그래프 표시
plt.figure(figsize=(10, 3))
for i in range(N):
    ax = plt.subplot(2, N/2, i + 1)
    plt.imshow(x_selected[i,1:].reshape(28, 28),cmap='gray_r')
    ax.set_title('%d:%d' % (y_selected[i], yp_test[i]),fontsize=14 )
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
